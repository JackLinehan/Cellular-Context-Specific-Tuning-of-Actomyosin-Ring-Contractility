# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import arviz as az
import pytensor as pt
import statistics as stats
from pymc.ode import DifferentialEquation
from scipy.integrate import odeint

# %%
DT = 0.25

my_num = 0

L = .5 

R = 0.013 

A = (5*L**2)/(108*(R**2/5 + L**2/54))

# %%
import scipy.io as io

data_gsc = io.loadmat("data/GSC_timealigned_data.mat")
ani_gsc = np.flip(data_gsc["ani_gsc_mean"].flatten())
ani_gsc_SE = np.flip(data_gsc["ani_gsc_SE"].flatten() )
nmy_gsc = np.flip(data_gsc["nmy_gsc_mean"].flatten())
nmy_gsc_SE = np.flip(data_gsc["nmy_gsc_SE"].flatten() )
circumference_gsc = np.flip(data_gsc["c_mean"].flatten() ) 
circumference_gsc_SE = np.flip(data_gsc["c_SE"].flatten() )

# %%
trace_apop_ani = list
trace_apop_nmy = list 
trace_gsc_ani = list 
trace_gsc_nmy = list 
trace_cell_ani = list 
trace_cell_nmy = list

# %%
def ringclose(r, t, p): 
    W = p[0]*nmy_gsc[0]*p[1]*ani_gsc[0]
    W2 = r[0]*p[4]*p[2]*p[3]*(W/(p[1]*ani_gsc[0] + p[2]*nmy_gsc[0])**2)
    return W2

times = DT*np.arange(0, 32,1)

x = np.matrix(circumference_gsc)
circumference_gsc1 = np.array(x.T)

x = np.matrix(circumference_gsc_SE) 
circumference_gsc_SE1 = np.array(x.T)

# %%
ode_model = DifferentialEquation(func = ringclose, times = times, n_states = 1, n_theta = 5, t0=0)
gammax = 1 
gammam = 1
constrained_prior_vp = pm.find_constrained_prior(pm.Gamma,lower= 0.0001, upper = 9, mass = .95, init_guess = dict(alpha=1,beta=1))

with pm.Model() as model:
    
    alpha = pm.Normal('alpha',mu = 0, sigma = 1)
    #gammam = pm.Normal('gammam', mu = 10^-6, sigma = 1) 
    v_p = pm.Gamma('v_p',**constrained_prior_vp)
    #gammax = pm.Normal('gammax', mu = 0, sigma = 1) 
    #sigma = pm.HalfCauchy("sigma", 1)
    sigma = circumference_gsc_SE1
    ode_solution = ode_model(y0 =circumference_gsc1[0], theta=[alpha, gammax, gammam, v_p, A])
    
    Y = pm.Normal("Y", mu= ode_solution, sigma = sigma, observed = circumference_gsc1)
    
    prior = pm.sample_prior_predictive(10) 
    trace = pm.sample(2000, tune = 1000, cores=1)
    posterior_predictive = pm.sample_posterior_predictive(trace)
# Out:
# Sampling: [Y, alpha, v_p]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [alpha, v_p]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 1633 seconds.
# There were 158 divergences after tuning. Increase `target_accept` or reparameterize.
# ...

# %%
az.plot_trace(trace)
# Out:
# array([[<Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'alpha'}>],
#        [<Axes: title={'center': 'v_p'}>, <Axes: title={'center': 'v_p'}>]],
#       dtype=object)

# %%
az.plot_pair(trace, var_names = ['v_p','alpha'], kind = 'kde', marginals = 'True', point_estimate = 'median')
# Out:
# array([[<Axes: >, None],
#        [<Axes: xlabel='v_p', ylabel='alpha'>, <Axes: >]], dtype=object)

# %%
np.median(alpha)

# %%
trace.unstack(inplace = "True")
a= az.extract(trace, group = 'posterior', var_names = ['alpha'], keep_dataset = 'true')
alpha = a.alpha.values

#a= az.extract(trace, group = 'posterior', var_names = ['gammax'], keep_dataset = 'true')
#gammax = a.gammax.values

#a= az.extract(trace, group = 'posterior', var_names = ['gammam'], keep_dataset = 'true')
#gammam = a.gammam.values

a= az.extract(trace, group = 'posterior', var_names = ['v_p'], keep_dataset = 'true')
v_p = a.v_p.values


active_stress = -((4*np.pi*R**3)/27)*(L**2)/12 * gammam*np.median(v_p)*nmy_gsc**2 * (np.median(alpha)*ani_gsc*gammam*nmy_gsc)/(gammax*ani_gsc + gammam*nmy_gsc)

viscosity = ((4*np.pi*R**3)/(15))*nmy_gsc**2 * (gammax*ani_gsc + gammam*nmy_gsc)*((R**2)/5 + L**2/54) 


alpha.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 trace.unstack(inplace = "True")
#       2 a= az.extract(trace, group = 'posterior', var_names = ['alpha'], keep_dataset = 'true')
#       3 alpha = a.alpha.values
#
# NameError: name 'trace' is not defined

# %%
gammax = .5 
gammam = 0.01
alpha = .1
v_p = 1000
stress = gammam*v_p*nmy_gsc**2 * (alpha*ani_gsc*gammam*nmy_gsc)/(gammax*ani_gsc + gammam*nmy_gsc)

visco = ((4*np.pi*R**3)/(15))*nmy_gsc**2 * (gammax*ani_gsc + gammam*nmy_gsc)*((R**2)/5 + L**2/54) 

plt.plot(visco/visco[0],stress/stress[0])
plt.plot(np.linspace(0,5,10),np.linspace(0,5,10))
plt.grid()

# %%
ani_rho = ani_gsc
nmy_rho = nmy_gsc
plt.plot(viscosity, active_stress)

# %%
mcmc_prediction = odeint(ringclose, t=times, y0 = circumference_gsc1[0], args = tuple([[np.median(alpha), gammax, gammam, np.median(v_p), A]]))

# %%
plt.plot(mcmc_prediction)
plt.plot(circumference_gsc)

# %%
io.savemat('GSC_VPA_A.mat', dict(alpha = alpha))

# %%
io.savemat('GSC_VPA_VP.mat', dict(v_p = v_p))
